# %%
import pandas as pd
import os
import itertools
from itertools import combinations, permutations
import random
import numpy as np

# %% [markdown]
# ## Generate names, places, locations and objects

# %%
name =  pd.read_csv('https://www.cs.cmu.edu/Groups/AI/util/areas/nlp/corpora/names/female.txt')[4:].sample(n=25, random_state = 88)['# List of common female names.'].values
place = ['bag','backpack', 'bin','box', 'briefcase',
         'cabinet', 'chest', 'coffer', 'chamber','locker','suitcase',
         'crate', 'tote', 'knapsack', 'hamper', 'carryall', 'drawer',
         'case', 'cupboard', 'pantry', 'safe',
         'refrigerator', 'closet']
location = ['attic', 'bedroom', 'study', 'garage', 'living room', 'basement', 'loft', 'kitchen', 'terrace', 'balcony', 'nursery',
            'conservatory', 'lounge', 'dining room', 'library',
            'farm', 'bar', 'market', 'garden', 'bank', 'office', 'factory',
            'house', 'hall', 'bathroom', 'shower room', 'storeroom', 'parking', 'squad room',
            'recreation room', 'locker room', 'belfry', 'classroom', 'barroom', 'lounge',
            'checkroom', 'guardroom', 'ballroom', 'cardroom', 'clubroom', 'boardroom',
            'dinette', 'compartment', 'reception room', 'reading room', 'smoking room', 'dance studio',
            'laundry room', 'waiting room', 'lobby']
objects = ['beet', 'broccoli', 'cabbage','carrot', 'corn', 'cucumber', 'cauliflower', 'eggplant', 'pepper', 'pumpkin', 'potato', 'tomato', 'zucchini',
         'banana', 'coconut', 'durian', 'grapefruit', 'guava', 'lemon', 'mango', 'melon', 'papaya', 'peach', 'pear', 'persimmon', 'pineapple', 'plum',
         'sweater', 'jacket', 'coat', 'vest', 'dress', 'sock', 'raincoat', 'skirt', 'blouse', 'shirt', 'tie', 'scarf', 'cap','ring', 'watch', 'cardigan', 'hoodie', 'mask', 'mitten',
         'binder', 'book', 'bottle', 'bulb', 'calculator', 'casette', 'chalk', 'pencil', 'compass', 'cork', 'crayon', 'cup', 'tape', 'fork', 'lock', 'marker', 'mug', 'notebook', 'pen', 'plate',
         'rubber', 'ruler', 'torch', 'cable',
         'knife', 'jar', 'sponge', 'towel', 'spoon', 'button', 'candle','hammer', 'key', 'magnet', 'thermometer']

# %% [markdown]
# ## Create Story template

# %%
class data_smarties:
  def __init__(self, name, obj, location, place, question):
    self.name = name ##[A,B]
    self.obj = obj ## [O1,O2]
    self.location = location ## L1
    self.place = place ##P1
    self.Q = question ##['reality', 'belief', '1stA', '1stB', '2ndA', '2ndB']
  def premise(self):
    sent1 = "{} found a {} in the {}.".format(self.name[0], self.place, self.location)
    sent2 = "The label on the {} says {}.".format(self.place, self.obj[0])
    sent3 = "{} couldn’t see what was inside the {}.".format(self.name[0], self.place)
    sent4 = "{} opened the {} and found a {}.".format(self.name[0], self.place, self.obj[1])
    sent5 = "There is no {} in the {}.".format(self.obj[0], self.place)
    sent6 = "{} closed the {} and put it back.".format(self.name[0], self.place)
    sent7 = "{} entered the {} and saw the {}.".format(self.name[1], self.location, self.place)
    return [sent1, sent2, sent3, sent4, sent5, sent6, sent7]

  def prompt(self):
    story = " ".join(self.premise())
    return story

  def question(self):
    if self.Q == 'reality':
      return 'What was in the {}?'.format(self.place)
    elif self.Q == 'belief':
      return 'What was supposed to be in the {}?'.format(self.place)
    elif self.Q =='1stA':
      return "After {} opened the {}, what would {} expect to find in the {}?".format(self.name[1], self.place, self.name[0], self.place)
    elif self.Q == '1stB':
      return "After {} opened the {}, what would {} expect to find in the {}?".format(self.name[1], self.place, self.name[1], self.place)
    elif self.Q == '2ndA':
      return "After {} opened the {}, what would {} think {} would expect to find in the {}?".format(self.name[1], self.place,  self.name[0], self.name[1], self.place)
    elif self.Q == '2ndB':
      return "After {} opened the {}, what would {} think {} would expect to find in the {}?".format(self.name[1], self.place, self.name[1], self.name[0], self.place)
  def answer(self):
    if self.Q == 'reality':
      return '{}'.format(self.obj[1])
    elif self.Q == 'belief':
      return '{}'.format(self.obj[0])
    elif self.Q == '1stA':
      return "{}".format(self.obj[1])
    elif self.Q =='1stB':
      return "{}".format(self.obj[0])
    elif self.Q == '2ndA':
      return "{}".format(self.obj[0])
    elif self.Q == '2ndB':
      return "{}".format(self.obj[0])
  def qa_prompt(self):
    start = 'Answer the question based on context:\n\nContext:'
    middle = "\nQuestion:\n"
    output = start + self.prompt() + middle + self.question()
    return output
  def mc_prompt(self):
    start = "Choose the correct answer from A or B for the following question:\nQuestion:\n"
    end = '\nA. {}\nB. {}'.format(self.obj[1], self.obj[0])
    output = start + self.prompt() + " " + self.question() + end
    return output
  def comp_prompt(self):
    start = "Complete the following paragraph:\n"
    if self.Q == 'reality':
      end = "In the {}, there was ".format(self.place)
    elif self.Q == 'belief':
      end = "In the {}, there was supposed to be ".format(self.place)
    elif self.Q =='1stA':
      end = "After {} opened the {}, {} would expect to find".format(self.name[1], self.place, self.name[0])
    elif self.Q == '1stB':
      end = "After {} opened the {}, {} would expect to find".format(self.name[1], self.place, self.name[1])
    elif self.Q == '2ndA':
      end = "After {} opened the {}, {} would think {} would expect to find".format(self.name[1], self.place, self.name[0], self.name[1])
    elif self.Q == '2ndB':
      end = "After {} opened the {}, {} would think {} would expect to find".format(self.name[1], self.place, self.name[1], self.name[0])
    output = start + self.prompt() + " " + end
    return output
  def fb_prompt(self):
    start = "Fill in the blank (< >):\n"
    middle = self.comp_prompt().split("\n")[-1].split(' ')
    middle[-1] = middle[-1] + " a <>."
    output = start + " ".join(middle)
    return output
  def tf_prompt(self):
    start = "Given the context, judge True or False of the given statements A and B respectively:\nContext:\n"
    middle = self.prompt() + " " + self.question() + "\nStatement:\n"
    if self.Q == "reality":
      statementA = "A. In the {}, there was a {}.\n".format(self.place, self.obj[1])
      statementB = "B. In the {}, there was a {}.\n".format(self.place, self.obj[0])
    elif self.Q == 'belief':
      statementA = "A. In the {}, there was supposed to be a {}.\n".format(self.place, self.obj[1])
      statementB = "B. In the {}, there was supposed to be a {}.\n".format(self.place, self.obj[0])
    elif self.Q =='1stA':
      statementA = "A. After {} opened the {}, {} would expect to find a {}.\n".format(self.name[1], self.place, self.name[0], self.obj[1])
      statementB = "B. After {} opened the {}, {} would expect to find a {}.\n".format(self.name[1], self.place,self.name[0], self.obj[0])
    elif self.Q == '1stB':
      statementA = "A. After {} opened the {}, {} would expect to find a {}.\n".format(self.name[1], self.place, self.name[1], self.obj[1])
      statementB = "B. After {} opened the {}, {} would expect to find a {}.\n".format(self.name[1], self.place, self.name[1], self.obj[0])
    elif self.Q == '2ndA':
      statementA = "A. After {} opened the {}, {} would think {} would expect to find a {}.\n".format(self.name[1], self.place, self.name[0], self.name[1], self.obj[1])
      statementB = "B. After {} opened the {}, {} would think {} would expect to find a {}.\n".format(self.name[1], self.place, self.name[0], self.name[1], self.obj[0])
    elif self.Q == '2ndB':
      statementA = "A. After {} opened the {}, {} would think {} would expect to find a {}.\n".format(self.name[1], self.place, self.name[1], self.name[0], self.obj[1])
      statementB = "B. After {} opened the {}, {} would think {} would expect to find a {}.\n".format(self.name[1], self.place, self.name[1], self.name[0], self.obj[0])
    end = "Use this format for the answer:\nA.\nB."
    output = start + middle + statementA  + statementB + end
    return output
  def tfr_prompt(self):
    start = "Given the context, reason through statements A and B step by step and provide a True or False judgment based on the reasoning:"
    output = "\n".join([start] + self.tf_prompt().split('\n')[1:])
    return output

# %%
class data_SallyAnne:
  def __init__(self, name, obj, location, place, question):
    self.name = name ##[A,B]
    self.obj = obj ## O1
    self.location = location ## L1
    self.place = place ## [P1,P2]
    self.Q = question ##['reality', 'belief', '1stA', '1stB', '2ndA', '2ndB']
  def premise(self):
    sent1 = "{} and {} were hanging out in the {}.".format(self.name[0], self.name[1],self.location)
    sent2 = "They saw a {} and a {}.".format(self.place[0], self.place[1])
    sent3 = "They found a {} in the {}.".format(self.obj, self.place[0])
    sent4 = "{} left the {}.".format(self.name[1], self.location)
    sent5 = "{} moved the {} to the {}.".format(self.name[0], self.obj, self.place[1])
    return [sent1, sent2, sent3, sent4, sent5]
  def prompt(self):
    story = " ".join(self.premise())
    return story
  def question(self):
    if self.Q == 'reality':
      return 'Where is the {} currently?'.format(self.obj)
    elif self.Q == 'belief':
      return 'Where was the {} previously?'.format(self.obj)
    elif self.Q =='1stA':
      return "After {} came back to the {}, where would {} look for the {}?".format(self.name[1], self.location, self.name[0], self.obj)
    elif self.Q == '1stB':
      return "After {} came back to the {}, where would {} look for the {}?".format(self.name[1], self.location, self.name[1], self.obj)
    elif self.Q == '2ndA':
      return "After {} came back to the {}, where would {} think {} would look for the {}?".format(self.name[1], self.location, self.name[0], self.name[1], self.obj)
    else:
      return "After {} came back to the {}, where would {} think {} would look for the {}?".format(self.name[1], self.location, self.name[1], self.name[0], self.obj)
  def answer(self):
    if self.Q == 'reality':
      return '{}'.format(self.place[1])
    elif self.Q == 'belief':
      return '{}'.format(self.place[0])
    elif self.Q == '1stA':
      return '{}'.format(self.place[1])
    elif self.Q == '1stB':
      return '{}'.format(self.place[0])
    elif self.Q == '2ndA':
      return '{}'.format(self.place[0])
    elif self.Q == '2ndB':
      return '{}'.format(self.place[0])
  def qa_prompt(self):
    start = 'Answer the question based on context:\n\nContext:'
    middle = "\nQuestion:\n"
    output = start + self.prompt() + middle + self.question()
    return output
  def mc_prompt(self):
    start = "Choose the correct answer from A or B for the following question:\nQuestion:\n"
    end = '\nA. {}\nB. {}'.format(self.obj[1], self.obj[0])
    output = start + self.prompt() + " " + self.question() + end
    return output
  def comp_prompt(self):
    start = "Complete the following paragraph:\n"
    if self.Q == 'reality':
      end = "Currently the {} is in".format(self.obj)
    elif self.Q == 'belief':
      end = "Previously the {} was in".format(self.obj)
    elif self.Q =='1stA':
      end = "After {} came back to the {}, {} would look for the {} in".format(self.name[1], self.location, self.name[0], self.obj)
    elif self.Q == '1stB':
      end = "After {} came back to the {}, {} would look for the {} in".format(self.name[1], self.location, self.name[1], self.obj)
    elif self.Q == '2ndA':
      end = "After {} came back to the {}, {} would think {} would look for the {} in".format(self.name[1], self.location, self.name[0], self.name[1], self.obj)
    elif self.Q == '2ndB':
      end = "After {} came back to the {}, {} would think {} would look for the {} in".format(self.name[1], self.location, self.name[1], self.name[0], self.obj)
    output = start + self.prompt() + " " + end
    return output
  def fb_prompt(self):
    start = "Fill in the blank (< >):\n"
    middle = self.comp_prompt().split("\n")[-1].split(' ')
    middle[-1] = middle[-1] + " the <>."
    output = start + " ".join(middle)
    return output
  def tf_prompt(self):
    start = "Given the context, judge True or False of the given statements A and B respectively:\nContext:\n"
    middle = self.prompt() + " " + self.question() + "\nStatement:\n"
    if self.Q == "reality":
      statementA = "A. Currently the {} is in the {}.\n".format(self.obj, self.place[1])
      statementB = "B. Currently the {} is in the {}.\n".format(self.obj, self.place[0])
    elif self.Q == 'belief':
      statementA = "A. Previously the {} was in the {}.\n".format(self.obj, self.place[1])
      statementB = "B. Previously the {} was in the {}.\n".format(self.obj, self.place[0])
    elif self.Q =='1stA':
      statementA = "A. After {} came back to the {}, {} would look for the {} in the {}.\n".format(self.name[1], self.location, self.name[0], self.obj, self.place[1])
      statementB = "B. After {} came back to the {}, {} would look for the {} in the {}.\n".format(self.name[1], self.location, self.name[0], self.obj, self.place[0])
    elif self.Q == '1stB':
      statementA = "A. After {} came back to the {}, {} would look for the {} in the {}.\n".format(self.name[1], self.location, self.name[1], self.obj, self.place[1])
      statementB = "B. After {} came back to the {}, {} would look for the {} in the {}.\n".format(self.name[1], self.location, self.name[1], self.obj, self.place[0])
    elif self.Q == '2ndA':
      statementA = "A. After {} came back to the {}, {} would think {} would look for the {} in the {}.\n".format(self.name[1], self.location, self.name[0], self.name[1], self.obj, self.place[1])
      statementB = "B. After {} came back to the {}, {} would think {} would look for the {} in the {}.\n".format(self.name[1], self.location, self.name[0], self.name[1], self.obj, self.place[0])
    elif self.Q == '2ndB':
      statementA = "A. After {} came back to the {}, {} would think {} would look for the {} in the {}.\n".format(self.name[1], self.location, self.name[1], self.name[0], self.obj, self.place[1])
      statementB = "B. After {} came back to the {}, {} would think {} would look for the {} in the {}.\n".format(self.name[1], self.location, self.name[1], self.name[0], self.obj, self.place[0])
    end = "Use this format for the answer:\nA.\nB."
    output = start + middle + statementA  + statementB + end
    return output
  def tfr_prompt(self):
    start = "Given the context, reason through statements A and B step by step and provide a True or False judgment based on the reasoning:"
    output = "\n".join([start] + self.tf_prompt().split('\n')[1:])
    return output

# %% [markdown]
# ## Generate stories

# %%
output_list_smarties = []
random.seed(42)
name_list = random.choices(list(permutations(name, 2)), k = 30)
object_list = random.choices(list(permutations(objects, 2)), k = 30)
for i in range(0, 30):
  n = name_list[i]
  p = place[i%len(place)]
  o = object_list[i]
  l = location[i%len(location)]
  for que in ['reality', 'belief', '1stA', '1stB', '2ndA', '2ndB']:
    smarties = data_smarties(n, o, l, p, que)
    output_list_smarties.append([smarties.prompt(), smarties.question(), smarties.answer(), que, i+1,
                                 smarties.qa_prompt(), smarties.comp_prompt(), smarties.fb_prompt(), smarties.mc_prompt(),
                                 smarties.tf_prompt(), smarties.tfr_prompt()])
df_smarties = pd.DataFrame(output_list_smarties, columns = ['prompt', 'question', 'short_answer', 'question_type', 'story_index',
                                                            'qa_prompt', 'comp_prompt', 'fb_prompt', 'mc_prompt', 'tf_prompt', 'tfr_prompt'])

# %%
output_list_sallyanne = []
random.seed(42)
name_list = random.choices(list(permutations(name, 2)), k = 30)
place_list = random.choices(list(permutations(place, 2))*5, k = 30)
for i in range(0, 30):
  n = name_list[i]
  p = place_list[i]
  o = object_list[i][0]
  l = location[i%len(location)]
  for que in ['reality', 'belief', '1stA', '1stB', '2ndA', '2ndB']:
    sally_anne = data_SallyAnne(n, o, l, p, que)
    output_list_sallyanne.append([sally_anne.prompt(), sally_anne.question(), sally_anne.answer(), que, i+1,
                                  sally_anne.qa_prompt(), sally_anne.comp_prompt(), sally_anne.fb_prompt(), sally_anne.mc_prompt(),
                                  sally_anne.tf_prompt(), sally_anne.tfr_prompt()])
df_sallyanne = pd.DataFrame(output_list_sallyanne, columns = ['prompt', 'question', 'short_answer', 'question_type', 'story_index',
                                                              'qa_prompt', 'comp_prompt', 'fb_prompt', 'mc_prompt', 'tf_prompt', 'tfr_prompt'])

# %%
df_smarties.head()
# Out:
#                                               prompt  \
# 0  Neila found a bag in the attic. The label on t...
# 1  Neila found a bag in the attic. The label on t...
# 2  Neila found a bag in the attic. The label on t...
# 3  Neila found a bag in the attic. The label on t...
# 4  Neila found a bag in the attic. The label on t...
#
#                                             question short_answer  \
# 0                               What was in the bag?         vest
# 1                What was supposed to be in the bag?        plate
# 2  After Juanita opened the bag, what would Neila...         vest
# 3  After Juanita opened the bag, what would Juani...        plate
# 4  After Juanita opened the bag, what would Neila...        plate
#
#   question_type  story_index  \
# 0       reality            1
# 1        belief            1
# 2          1stA            1
# 3          1stB            1
# 4          2ndA            1
#
#                                            qa_prompt  \
# 0  Answer the question based on context:\n\nConte...
# 1  Answer the question based on context:\n\nConte...
# 2  Answer the question based on context:\n\nConte...
# 3  Answer the question based on context:\n\nConte...
# 4  Answer the question based on context:\n\nConte...
#
#                                          comp_prompt  \
# 0  Complete the following paragraph:\nNeila found...
# 1  Complete the following paragraph:\nNeila found...
# 2  Complete the following paragraph:\nNeila found...
# 3  Complete the following paragraph:\nNeila found...
# 4  Complete the following paragraph:\nNeila found...
#
#                                            fb_prompt  \
# 0  Fill in the blank (< >):\nNeila found a bag in...
# 1  Fill in the blank (< >):\nNeila found a bag in...
# 2  Fill in the blank (< >):\nNeila found a bag in...
# 3  Fill in the blank (< >):\nNeila found a bag in...
# 4  Fill in the blank (< >):\nNeila found a bag in...
#
#                                            mc_prompt  \
# 0  Choose the correct answer from A or B for the ...
# 1  Choose the correct answer from A or B for the ...
# 2  Choose the correct answer from A or B for the ...
# 3  Choose the correct answer from A or B for the ...
# 4  Choose the correct answer from A or B for the ...
#
#                                            tf_prompt  \
# 0  Given the context, judge True or False of the ...
# 1  Given the context, judge True or False of the ...
# 2  Given the context, judge True or False of the ...
# 3  Given the context, judge True or False of the ...
# 4  Given the context, judge True or False of the ...
#
#                                           tfr_prompt
# 0  Given the context, reason through statements A...
# 1  Given the context, reason through statements A...
# 2  Given the context, reason through statements A...
# 3  Given the context, reason through statements A...
# 4  Given the context, reason through statements A...

# %%
df_sallyanne.head()
# Out:
#                                               prompt  \
# 0  Neila and Juanita were hanging out in the atti...
# 1  Neila and Juanita were hanging out in the atti...
# 2  Neila and Juanita were hanging out in the atti...
# 3  Neila and Juanita were hanging out in the atti...
# 4  Neila and Juanita were hanging out in the atti...
#
#                                             question short_answer  \
# 0                      Where is the plate currently?       pantry
# 1                    Where was the plate previously?          bag
# 2  After Juanita came back to the attic, where wo...       pantry
# 3  After Juanita came back to the attic, where wo...          bag
# 4  After Juanita came back to the attic, where wo...          bag
#
#   question_type  story_index  \
# 0       reality            1
# 1        belief            1
# 2          1stA            1
# 3          1stB            1
# 4          2ndA            1
#
#                                            qa_prompt  \
# 0  Answer the question based on context:\n\nConte...
# 1  Answer the question based on context:\n\nConte...
# 2  Answer the question based on context:\n\nConte...
# 3  Answer the question based on context:\n\nConte...
# 4  Answer the question based on context:\n\nConte...
#
#                                          comp_prompt  \
# 0  Complete the following paragraph:\nNeila and J...
# 1  Complete the following paragraph:\nNeila and J...
# 2  Complete the following paragraph:\nNeila and J...
# 3  Complete the following paragraph:\nNeila and J...
# 4  Complete the following paragraph:\nNeila and J...
#
#                                            fb_prompt  \
# 0  Fill in the blank (< >):\nNeila and Juanita we...
# 1  Fill in the blank (< >):\nNeila and Juanita we...
# 2  Fill in the blank (< >):\nNeila and Juanita we...
# 3  Fill in the blank (< >):\nNeila and Juanita we...
# 4  Fill in the blank (< >):\nNeila and Juanita we...
#
#                                            mc_prompt  \
# 0  Choose the correct answer from A or B for the ...
# 1  Choose the correct answer from A or B for the ...
# 2  Choose the correct answer from A or B for the ...
# 3  Choose the correct answer from A or B for the ...
# 4  Choose the correct answer from A or B for the ...
#
#                                            tf_prompt  \
# 0  Given the context, judge True or False of the ...
# 1  Given the context, judge True or False of the ...
# 2  Given the context, judge True or False of the ...
# 3  Given the context, judge True or False of the ...
# 4  Given the context, judge True or False of the ...
#
#                                           tfr_prompt
# 0  Given the context, reason through statements A...
# 1  Given the context, reason through statements A...
# 2  Given the context, reason through statements A...
# 3  Given the context, reason through statements A...
# 4  Given the context, reason through statements A...
